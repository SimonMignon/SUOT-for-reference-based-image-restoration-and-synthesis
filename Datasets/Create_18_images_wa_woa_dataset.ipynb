# %%
import os
import shutil
import csv
from PIL import Image

def create_image_pairs_list(csv_file_path,MvTec_path):
    """
    Reads a CSV file containing pairs of image paths and returns a list of tuples,
    where each tuple contains the pair of image paths.
    
    Args:
    - csv_file_path (str): The path to the CSV file.
    
    Returns:
    - List[Tuple[str, str, str]]: A list of tuples, where each tuple contains a trio of image paths.
    """
    image_pairs = []
    with open(csv_file_path, 'r') as file:
        for line in file:
            image_path_1, image_path_2, image_path_3 = line.strip().split(',')
            image_pairs.append((MvTec_path+image_path_1, MvTec_path+image_path_2, MvTec_path+image_path_3))

    return image_pairs

def convert_to_rgb(source_folders, image_indices):
    """
    Converts images specified by their indices to RGB for each given source folder.
    
    Args:
    - source_folders (list of str): List of folders containing images to be converted.
    - image_indices (list of int): List of image indices to convert.
    """
    for folder in source_folders:
        for index in image_indices:
            # Construit le chemin de l'image basé sur l'index
            # Assurez-vous que le formatage correspond à celui utilisé lors de la création des fichiers
            if index < 10:
                image_name = f"00{index}.png"
            else:
                image_name = f"0{index}.png"
            image_path = os.path.join(folder, image_name)
            
            # Ouvre l'image en nuances de gris
            image = Image.open(image_path).convert('RGB')
            
            # Sauvegarde l'image en format RGB
            image.save(image_path)
            print(f"Image converted to RGB : {image_path}")

# Path to MvTec
MvTec_path= '/home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/'
            
# Load path to images in MvTec
csv_file_path = '18_images_wa_woa_dataset_path.csv'

# images PATH
image_pairs_list = create_image_pairs_list(csv_file_path,MvTec_path)  

# Copy images in a new folder + rename
list_folders = ["18_images_wa_woa_dataset/HR", "18_images_wa_woa_dataset/HR_with_anomalies", "18_images_wa_woa_dataset/HR_without_anomalies"]
for j in range(3):
    # Create folder if doesn't exist
    if not os.path.exists(list_folders[j]):
        os.makedirs(list_folders[j])
    for i, img_paths in enumerate(image_pairs_list):
        # new img name
        if i < 10:
            new_name = f"00{i}.png"
        else:
            new_name = f"0{i}.png"
        destination_path = os.path.join(list_folders[j], new_name)
        shutil.copy(img_paths[j], destination_path)
        print(f"Copy : {img_paths[j]} -> {destination_path}")

# Defines source folders and indexes for images to be converted to RGB
source_folders = ["18_images_wa_woa_dataset/HR", "18_images_wa_woa_dataset/HR_with_anomalies", "18_images_wa_woa_dataset/HR_without_anomalies"]
image_indices = [14, 15]

# Calls the conversion function
convert_to_rgb(source_folders, image_indices)
# Out:
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/bottle/test/good/000.png -> 18_images_wa_woa_dataset/HR/000.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/bottle/test/good/001.png -> 18_images_wa_woa_dataset/HR/001.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/carpet/test/good/000.png -> 18_images_wa_woa_dataset/HR/002.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/carpet/test/good/001.png -> 18_images_wa_woa_dataset/HR/003.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/hazelnut/test/good/000.png -> 18_images_wa_woa_dataset/HR/004.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/hazelnut/test/good/035.png -> 18_images_wa_woa_dataset/HR/005.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/capsule/test/good/001.png -> 18_images_wa_woa_dataset/HR/006.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/capsule/test/good/000.png -> 18_images_wa_woa_dataset/HR/007.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/pill/test/good/024.png -> 18_images_wa_woa_dataset/HR/008.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/pill/test/good/025.png -> 18_images_wa_woa_dataset/HR/009.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/wood/test/good/004.png -> 18_images_wa_woa_dataset/HR/010.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/wood/test/good/007.png -> 18_images_wa_woa_dataset/HR/011.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/leather/test/good/001.png -> 18_images_wa_woa_dataset/HR/012.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/leather/test/good/000.png -> 18_images_wa_woa_dataset/HR/013.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/grid/test/good/013.png -> 18_images_wa_woa_dataset/HR/014.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/grid/test/good/007.png -> 18_images_wa_woa_dataset/HR/015.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/tile/test/good/032.png -> 18_images_wa_woa_dataset/HR/016.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/tile/test/good/002.png -> 18_images_wa_woa_dataset/HR/017.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/bottle/test/contamination/005.png -> 18_images_wa_woa_dataset/HR_with_anomalies/000.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/bottle/test/contamination/007.png -> 18_images_wa_woa_dataset/HR_with_anomalies/001.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/carpet/test/color/000.png -> 18_images_wa_woa_dataset/HR_with_anomalies/002.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/carpet/test/color/008.png -> 18_images_wa_woa_dataset/HR_with_anomalies/003.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/hazelnut/test/crack/015.png -> 18_images_wa_woa_dataset/HR_with_anomalies/004.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/hazelnut/test/print/008.png -> 18_images_wa_woa_dataset/HR_with_anomalies/005.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/capsule/test/poke/000.png -> 18_images_wa_woa_dataset/HR_with_anomalies/006.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/capsule/test/crack/001.png -> 18_images_wa_woa_dataset/HR_with_anomalies/007.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/pill/test/color/006.png -> 18_images_wa_woa_dataset/HR_with_anomalies/008.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/pill/test/color/022.png -> 18_images_wa_woa_dataset/HR_with_anomalies/009.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/wood/test/hole/004.png -> 18_images_wa_woa_dataset/HR_with_anomalies/010.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/wood/test/color/006.png -> 18_images_wa_woa_dataset/HR_with_anomalies/011.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/leather/test/cut/018.png -> 18_images_wa_woa_dataset/HR_with_anomalies/012.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/leather/test/glue/000.png -> 18_images_wa_woa_dataset/HR_with_anomalies/013.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/grid/test/thread/010.png -> 18_images_wa_woa_dataset/HR_with_anomalies/014.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/grid/test/thread/004.png -> 18_images_wa_woa_dataset/HR_with_anomalies/015.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/tile/test/rough/009.png -> 18_images_wa_woa_dataset/HR_with_anomalies/016.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/tile/test/crack/010.png -> 18_images_wa_woa_dataset/HR_with_anomalies/017.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/bottle/train/good/000.png -> 18_images_wa_woa_dataset/HR_without_anomalies/000.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/bottle/train/good/001.png -> 18_images_wa_woa_dataset/HR_without_anomalies/001.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/carpet/train/good/000.png -> 18_images_wa_woa_dataset/HR_without_anomalies/002.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/carpet/train/good/001.png -> 18_images_wa_woa_dataset/HR_without_anomalies/003.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/hazelnut/train/good/047.png -> 18_images_wa_woa_dataset/HR_without_anomalies/004.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/hazelnut/train/good/008.png -> 18_images_wa_woa_dataset/HR_without_anomalies/005.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/capsule/train/good/003.png -> 18_images_wa_woa_dataset/HR_without_anomalies/006.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/capsule/train/good/001.png -> 18_images_wa_woa_dataset/HR_without_anomalies/007.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/pill/train/good/060.png -> 18_images_wa_woa_dataset/HR_without_anomalies/008.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/pill/train/good/155.png -> 18_images_wa_woa_dataset/HR_without_anomalies/009.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/wood/train/good/007.png -> 18_images_wa_woa_dataset/HR_without_anomalies/010.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/wood/train/good/004.png -> 18_images_wa_woa_dataset/HR_without_anomalies/011.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/leather/train/good/000.png -> 18_images_wa_woa_dataset/HR_without_anomalies/012.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/leather/train/good/001.png -> 18_images_wa_woa_dataset/HR_without_anomalies/013.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/grid/train/good/037.png -> 18_images_wa_woa_dataset/HR_without_anomalies/014.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/grid/train/good/036.png -> 18_images_wa_woa_dataset/HR_without_anomalies/015.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/tile/train/good/009.png -> 18_images_wa_woa_dataset/HR_without_anomalies/016.png
# Copy : /home/prof/smignon/ot_patch_denoising/Wasserstein_Patch_Prior/GitHub_dossiers_lourds/MvTec_anomaly_detection_dataset/tile/train/good/001.png -> 18_images_wa_woa_dataset/HR_without_anomalies/017.png
# Image converted to RGB : 18_images_wa_woa_dataset/HR/014.png
# Image converted to RGB : 18_images_wa_woa_dataset/HR/015.png
# Image converted to RGB : 18_images_wa_woa_dataset/HR_with_anomalies/014.png
# Image converted to RGB : 18_images_wa_woa_dataset/HR_with_anomalies/015.png
# Image converted to RGB : 18_images_wa_woa_dataset/HR_without_anomalies/014.png
# Image converted to RGB : 18_images_wa_woa_dataset/HR_without_anomalies/015.png
